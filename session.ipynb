# %%
with open('cookie.txt') as f:
    lines = f.readlines()

lines
# Out:
# ['Domain: academic-accelerator.com\n',
#  'Path: /cdn-cgi/challenge-platform/h/g/flow/ov1/0.1587334158874388:1659323161:NNeXtmYnv1ZmYoGUp09knNreR7y9_RBV34q5k2oNvM8/733ba0bada111100\n',
#  'Name: cf_chl_seq_ed090d059ed650f\n',
#  'Expiration Date: undefined\n',
#  'Host: true\n',
#  'HTTP: true\n',
#  'Site Status: strict\n',
#  'Marked as Secure: strict\n',
#  'Session: true\n',
#  'Store ID: 0\n',
#  'Value: xKUYSHVzW8YXkT5\n',
#  '\n',
#  'Domain: machinelearningmastery.com\n',
#  'Path: /upsampling-and-transpose-convolution-layers-for-generative-adversarial-networks\n',
#  'Name: usprivacy\n',
#  'Expiration Date: undefined\n',
#  'Host: true\n',
#  'HTTP: false\n',
#  'Site Status: unspecified\n',
#  'Marked as Secure: unspecified\n',
#  'Session: true\n',
#  'Store ID: 0\n',
#  'Value: 1---\n',
#  '\n',
#  'Domain: .machinelearningmastery.com\n',
#  'Path: /upsampling-and-transpose-convolution-layers-for-generative-adversarial-networks\n',
#  'Name: __qca\n',
# ...
